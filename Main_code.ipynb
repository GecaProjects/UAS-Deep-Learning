# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, SpatialDropout1D, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import re
import itertools

# %%
# Seed untuk reproduktifitas
np.random.seed(1507)

# Membaca dataset yang diperbarui
file_path = 'https://raw.githubusercontent.com/syifaghaisani/UAS-Deep-Learning/27fb5a3233e7a8a9c92382478dc3789011bc1a61/tweets-bm%20-labelling.csv'
df = pd.read_csv(file_path)

# %%
df.columns
# Out:
# Index(['id_', 'created_at', 'tweetID', 'tweet', 'username', 'Akun', 'id_str',
#        'name', 'entity', 'commentcount', 'likes', 'retweets', 'quotes',
#        'replies', 'sentiment', 'bidang', 'gender', 'link', 'imageUrl'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_           2124 non-null   int64
#  1   created_at    2124 non-null   object
#  2   tweetID       2124 non-null   object
#  3   tweet         2124 non-null   object
#  4   username      2124 non-null   object
#  5   Akun          2124 non-null   object
#  6   id_str        2124 non-null   int64
#  7   name          2124 non-null   object
#  8   entity        2124 non-null   object
#  9   commentcount  1879 non-null   float64
#  10  likes         1602 non-null   float64
#  11  retweets      1602 non-null   float64
#  12  quotes        1602 non-null   float64
#  13  replies       2124 non-null   int64
#  14  sentiment     0 non-null      float64
#  15  bidang        0 non-null      float64
#  16  gender        0 non-null      float64
#  17  link          2124 non-null   object
#  18  imageUrl      2119 non-null   object
# dtypes: float64(7), int64(3), object(9)
# memory usage: 315.4+ KB

# %%
df.head()
# Out:
#    id_           created_at              tweetID  \
# 0    1  2023-01-01 13:50:44  1609547674893844481
# 1    2  2023-01-01 11:00:01  1609504712012795907
# 2    3   2023-01-02 9:41:59  1609847465347543042
# 3    4   2023-01-03 7:19:49  1610174074210160641
# 4    5   2023-01-03 2:29:01  1610100893583806465
#
#                                                tweet        username  \
# 0  Hallo, sobat Nedutase Lepas Sambut Kepala SMK ...    TangselSmkn2
# 1  Shin Tae-yong selaku pelatih kepala Timnas Ind...            PSSI
# 2  SUZUKI XL 7 Jawabannya! Tampilan eksterior Suz...   GampongSuzuki
# 3  Baru saja mengirim foto @ TOYOTA PERINTIS GATS...  toyotamedan_id
# 4  DIJUAL BMW E30 318i Mesin M10 Plat R Pajak On ...    HoldenKlasik
#
#                      Akun               id_str                       name  \
# 0  AkunMediaMasa/Instansi  1414792059257380864               SMKN2Tangsel
# 1  AkunMediaMasa/Instansi           2363027508                       PSSI
# 2              AkunBisnis            971377286             Gampong Suzuki
# 3              AkunBisnis            732457105  Toyota Medan 082167506001
# 4              AkunBisnis           1391235014             Suka Mobil Tua
#
#        entity  commentcount      likes  retweets   quotes  replies  sentiment  \
# 0    Daihatsu           0.0        NaN       NaN      NaN        1        NaN
# 1  Mitsubishi          31.0  1837302.0     159.0  24686.0       31        NaN
# 2      Suzuki           0.0      140.0      72.0   1510.0        0        NaN
# 3      Toyota           0.0      642.0       1.0    757.0        0        NaN
# 4         BMW           1.0   154655.0     402.0  96590.0        1        NaN
#
#    bidang  gender                                               link  \
# 0     NaN     NaN                   https://twitter.com/TangselSmkn2
# 1     NaN     NaN  https://twitter.com/PSSI/status/16095047120127...
# 2     NaN     NaN  https://twitter.com/GampongSuzuki/status/16098...
# 3     NaN     NaN  https://twitter.com/toyotamedan_id/status/1610...
# 4     NaN     NaN  https://twitter.com/HoldenKlasik/status/161010...
#
#                                             imageUrl
# 0  https://pbs.twimg.com/profile_images/155974970...
# 1  https://pbs.twimg.com/media/FlYVvBCaUAA-LHy.jp...
# 2  https://pbs.twimg.com/media/FldTuxJakAQTrqR.jp...
# 3  https://pbs.twimg.com/profile_images/147098860...
# 4  https://pbs.twimg.com/media/Flg6NOsaUAAS5FA.jp...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_           2124 non-null   int64
#  1   created_at    2124 non-null   object
#  2   tweetID       2124 non-null   object
#  3   tweet         2124 non-null   object
#  4   username      2124 non-null   object
#  5   Akun          2124 non-null   object
#  6   id_str        2124 non-null   int64
#  7   name          2124 non-null   object
#  8   entity        2124 non-null   object
#  9   commentcount  1879 non-null   float64
#  10  likes         1602 non-null   float64
#  11  retweets      1602 non-null   float64
#  12  quotes        1602 non-null   float64
#  13  replies       2124 non-null   int64
#  14  sentiment     0 non-null      float64
#  15  bidang        0 non-null      float64
#  16  gender        0 non-null      float64
#  17  link          2124 non-null   object
#  18  imageUrl      2119 non-null   object
# dtypes: float64(7), int64(3), object(9)
# memory usage: 315.4+ KB

# %%
print(df['Akun'].value_counts())
# Out:
# Akun
# AkunBisnis                695
# AkunPribadi               596
# AkunMediaMasa/Instansi    519
# Unknown                   314
# Name: count, dtype: int64

# %% [markdown]
# #**PERBAIKAN MODEL (Model awal ada di bawah)**

# %% [markdown]
# #**Tanpa Menghapus Duplikat**

# %% [markdown]
# #Epoch 10

# %%
# 1. Menghapus angka dan mengubah huruf menjadi lowercase
df['username'] = df['username'].str.replace(r'\d+', '', regex=True).str.lower()

# 2. Menghapus simbol atau karakter spesial
df['username'] = df['username'].str.replace(r'[^\w\s]', '', regex=True)

# 3. Menghapus pengulangan kata
df['username'] = df['username'].apply(lambda x: ' '.join(sorted(set(x.split()), key=x.split().index)))

# 4. Memisahkan kata berdasarkan suku kata
# Misalnya, gunakan pendekatan sederhana memisahkan berdasarkan vokal
def split_syllables(word):
    syllables = re.findall(r'[^aiueo]*[aiueo]+(?:[^aiueo]|$)', word)
    return ' '.join(syllables)

df['username'] = df['username'].apply(lambda x: ' '.join([split_syllables(word) for word in x.split()]))

# Definisikan kriteria pengelompokan
personal_keywords = ["itsme", "mas", "pak", "bu", "bapak", "bunda", "bang", "bung", "muhammad", "muhamad", "zulkifli", "fuad", "faisal",
                     "aziz", "nur", "rifky", "tiwi", "kikim", "artha", "shandra", "sinatria", "zahra", "khairun", "budi", "eka", "ridwan"]

business_keywords = ["id", "honda", "yamaha", "daihatsu", "wuling", "toyota", "hyundai", "suzuki", "mobil", "jok", "bisnis",
                     "bmw", "klasik", "mobil", "indonesia"]

media_keywords = ["smk", "polri", "tv", "news", "online", "post", "kota", "harian", "fm", "radio", "tempo", "tribun", "kompas",
                  "detik", "berita", "tirtoid", "solopos", "antara", "media", "polda", "polsek", "dpc", "dpp", "liputan",
                  "times", "jpnn", "cnn", "coid", "harian", "dotco", "cnbc", "info", "detik", "tribun", "cnn"]

unknown_keywords = ["photo", "php", "reel", "speed", "gaya", "tetangga", "merapi", "geger", "cat", "random"]

def categorize_username(username):
    if any(keyword in username for keyword in personal_keywords):
        return 'AkunPribadi'
    elif any(keyword in username for keyword in business_keywords):
        return 'AkunBisnis'
    elif any(keyword in username for keyword in media_keywords):
        return 'AkunMediaMasa/Institusi'
    elif any(keyword in username for keyword in unknown_keywords):
        return 'Unknown'
    elif sum(c.isdigit() for c in username) > sum(c.isalpha() for c in username):
        return 'Unknown'
    else:
        return 'Unknown'

# Terapkan fungsi pengelompokan pada dataset
df['account_type'] = df['username'].apply(categorize_username)

# Encode label
label_encoder = LabelEncoder()
df['account_type'] = label_encoder.fit_transform(df['account_type'])

# Tokenize username
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['username'])
sequences = tokenizer.texts_to_sequences(df['username'])
X = pad_sequences(sequences, maxlen=15)  # 15 adalah panjang maksimal username yang akan dipertimbangkan
y = df['account_type']

# Pisahkan data menjadi training dan testing set (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1507)

# Bangun model LSTM
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50, input_length=15))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(4, activation='softmax'))  # 4 kelas output

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Menyimpan model terbaik berdasarkan akurasi validasi
checkpoint = ModelCheckpoint('lstm_twitter_awal_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Latih model
history = model.fit(X_train, y_train, epochs=10, batch_size=224, validation_data=(X_test, y_test), verbose=2, callbacks=[checkpoint])

# Evaluasi model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.80471, saving model to lstm_twitter_awal_model.h5
# 8/8 - 16s - loss: 1.2866 - accuracy: 0.7716 - val_loss: 1.0831 - val_accuracy: 0.8047 - 16s/epoch - 2s/step
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.7870 - accuracy: 0.8334 - val_loss: 0.8747 - val_accuracy: 0.8047 - 751ms/epoch - 94ms/step
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.6359 - accuracy: 0.8334 - val_loss: 0.6372 - val_accuracy: 0.8047 - 735ms/epoch - 92ms/step
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.5691 - accuracy: 0.8334 - val_loss: 0.6189 - val_accuracy: 0.8047 - 743ms/epoch - 93ms/step
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.5321 - accuracy: 0.8334 - val_loss: 0.6305 - val_accuracy: 0.8047 - 678ms/epoch - 85ms/step
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.5201 - accuracy: 0.8334 - val_loss: 0.5857 - val_accuracy: 0.8047 - 687ms/epoch - 86ms/step
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.4881 - accuracy: 0.8334 - val_loss: 0.5505 - val_accuracy: 0.8047 - 720ms/epoch - 90ms/step
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.4498 - accuracy: 0.8334 - val_loss: 0.5100 - val_accuracy: 0.8047 - 1s/epoch - 183ms/step
# Epoch 9/10
#
# Epoch 9: val_accuracy improved from 0.80471 to 0.83059, saving model to lstm_twitter_awal_model.h5
# 8/8 - 2s - loss: 0.3990 - accuracy: 0.8381 - val_loss: 0.4574 - val_accuracy: 0.8306 - 2s/epoch - 203ms/step
# Epoch 10/10
#
# Epoch 10: val_accuracy improved from 0.83059 to 0.88000, saving model to lstm_twitter_awal_model.h5
# 8/8 - 2s - loss: 0.3422 - accuracy: 0.8870 - val_loss: 0.4067 - val_accuracy: 0.8800 - 2s/epoch - 204ms/step
# Accuracy: 0.8799999952316284

# %%
# Define the plot_training_history function
def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Visualisasi Loss dan Akurasi
plot_training_history(history) # Call the function after it's defined

# %% [markdown]
# #Epoch 20

# %%
# 1. Menghapus angka dan mengubah huruf menjadi lowercase
df['username'] = df['username'].str.replace(r'\d+', '', regex=True).str.lower()

# 2. Menghapus simbol atau karakter spesial
df['username'] = df['username'].str.replace(r'[^\w\s]', '', regex=True)

# 3. Menghapus pengulangan kata
df['username'] = df['username'].apply(lambda x: ' '.join(sorted(set(x.split()), key=x.split().index)))

# 4. Memisahkan kata berdasarkan suku kata
# Misalnya, gunakan pendekatan sederhana memisahkan berdasarkan vokal
def split_syllables(word):
    syllables = re.findall(r'[^aiueo]*[aiueo]+(?:[^aiueo]|$)', word)
    return ' '.join(syllables)

df['username'] = df['username'].apply(lambda x: ' '.join([split_syllables(word) for word in x.split()]))

# Definisikan kriteria pengelompokan
personal_keywords = ["itsme", "mas", "pak", "bu", "bapak", "bunda", "bang", "bung", "muhammad", "muhamad", "zulkifli", "fuad", "faisal",
                     "aziz", "nur", "rifky", "tiwi", "kikim", "artha", "shandra", "sinatria", "zahra", "khairun", "budi", "eka", "ridwan"]

business_keywords = ["id", "honda", "yamaha", "daihatsu", "wuling", "toyota", "hyundai", "suzuki", "mobil", "jok", "bisnis",
                     "bmw", "klasik", "mobil", "indonesia"]

media_keywords = ["smk", "polri", "tv", "news", "online", "post", "kota", "harian", "fm", "radio", "tempo", "tribun", "kompas",
                  "detik", "berita", "tirtoid", "solopos", "antara", "media", "polda", "polsek", "dpc", "dpp", "liputan",
                  "times", "jpnn", "cnn", "coid", "harian", "dotco", "cnbc", "info", "detik", "tribun", "cnn"]

unknown_keywords = ["photo", "php", "reel", "speed", "gaya", "tetangga", "merapi", "geger", "cat", "random"]

def categorize_username(username):
    if any(keyword in username for keyword in personal_keywords):
        return 'AkunPribadi'
    elif any(keyword in username for keyword in business_keywords):
        return 'AkunBisnis'
    elif any(keyword in username for keyword in media_keywords):
        return 'AkunMediaMasa/Institusi'
    elif any(keyword in username for keyword in unknown_keywords):
        return 'Unknown'
    elif sum(c.isdigit() for c in username) > sum(c.isalpha() for c in username):
        return 'Unknown'
    else:
        return 'Unknown'

# Terapkan fungsi pengelompokan pada dataset
df['account_type'] = df['username'].apply(categorize_username)

# Encode label
label_encoder = LabelEncoder()
df['account_type'] = label_encoder.fit_transform(df['account_type'])

# Tokenize username
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['username'])
sequences = tokenizer.texts_to_sequences(df['username'])
X = pad_sequences(sequences, maxlen=15)  # 15 adalah panjang maksimal username yang akan dipertimbangkan
y = df['account_type']

# Pisahkan data menjadi training dan testing set (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1507)

# Bangun model LSTM
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50, input_length=15))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(4, activation='softmax'))  # 4 kelas output

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Menyimpan model terbaik berdasarkan akurasi validasi
checkpoint = ModelCheckpoint('lstm_twitter_fix_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Latih model
history = model.fit(X_train, y_train, epochs=20, batch_size=224, validation_data=(X_test, y_test), verbose=2, callbacks=[checkpoint])

# Evaluasi model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/20
#
# Epoch 1: val_accuracy improved from -inf to 0.80471, saving model to lstm_twitter_fix_model.h5
# 8/8 - 8s - loss: 1.2965 - accuracy: 0.7463 - val_loss: 1.1192 - val_accuracy: 0.8047 - 8s/epoch - 993ms/step
# Epoch 2/20
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.8319 - accuracy: 0.8334 - val_loss: 0.8278 - val_accuracy: 0.8047 - 1s/epoch - 182ms/step
# Epoch 3/20
#
# Epoch 3: val_accuracy did not improve from 0.80471
# 8/8 - 2s - loss: 0.6361 - accuracy: 0.8334 - val_loss: 0.6369 - val_accuracy: 0.8047 - 2s/epoch - 194ms/step
# Epoch 4/20
#
# Epoch 4: val_accuracy did not improve from 0.80471
# 8/8 - 2s - loss: 0.5712 - accuracy: 0.8334 - val_loss: 0.6172 - val_accuracy: 0.8047 - 2s/epoch - 192ms/step
# Epoch 5/20
#
# Epoch 5: val_accuracy did not improve from 0.80471
# 8/8 - 2s - loss: 0.5317 - accuracy: 0.8334 - val_loss: 0.6270 - val_accuracy: 0.8047 - 2s/epoch - 188ms/step
# Epoch 6/20
#
# Epoch 6: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.5168 - accuracy: 0.8334 - val_loss: 0.5786 - val_accuracy: 0.8047 - 1s/epoch - 180ms/step
# Epoch 7/20
#
# Epoch 7: val_accuracy did not improve from 0.80471
# 8/8 - 2s - loss: 0.4810 - accuracy: 0.8334 - val_loss: 0.5435 - val_accuracy: 0.8047 - 2s/epoch - 217ms/step
# Epoch 8/20
#
# Epoch 8: val_accuracy did not improve from 0.80471
# 8/8 - 1s - loss: 0.4403 - accuracy: 0.8334 - val_loss: 0.4999 - val_accuracy: 0.8047 - 1s/epoch - 150ms/step
# Epoch 9/20
#
# Epoch 9: val_accuracy improved from 0.80471 to 0.87059, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.3874 - accuracy: 0.8534 - val_loss: 0.4405 - val_accuracy: 0.8706 - 936ms/epoch - 117ms/step
# Epoch 10/20
#
# Epoch 10: val_accuracy improved from 0.87059 to 0.88471, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.3248 - accuracy: 0.9070 - val_loss: 0.3887 - val_accuracy: 0.8847 - 924ms/epoch - 116ms/step
# Epoch 11/20
#
# Epoch 11: val_accuracy improved from 0.88471 to 0.90588, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.2618 - accuracy: 0.9323 - val_loss: 0.3419 - val_accuracy: 0.9059 - 928ms/epoch - 116ms/step
# Epoch 12/20
#
# Epoch 12: val_accuracy improved from 0.90588 to 0.90824, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.2184 - accuracy: 0.9435 - val_loss: 0.3054 - val_accuracy: 0.9082 - 926ms/epoch - 116ms/step
# Epoch 13/20
#
# Epoch 13: val_accuracy improved from 0.90824 to 0.92000, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.1839 - accuracy: 0.9488 - val_loss: 0.2839 - val_accuracy: 0.9200 - 939ms/epoch - 117ms/step
# Epoch 14/20
#
# Epoch 14: val_accuracy did not improve from 0.92000
# 8/8 - 1s - loss: 0.1531 - accuracy: 0.9541 - val_loss: 0.2661 - val_accuracy: 0.9200 - 894ms/epoch - 112ms/step
# Epoch 15/20
#
# Epoch 15: val_accuracy improved from 0.92000 to 0.92235, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.1369 - accuracy: 0.9541 - val_loss: 0.2534 - val_accuracy: 0.9224 - 933ms/epoch - 117ms/step
# Epoch 16/20
#
# Epoch 16: val_accuracy improved from 0.92235 to 0.92471, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.1217 - accuracy: 0.9564 - val_loss: 0.2478 - val_accuracy: 0.9247 - 820ms/epoch - 103ms/step
# Epoch 17/20
#
# Epoch 17: val_accuracy did not improve from 0.92471
# 8/8 - 1s - loss: 0.1120 - accuracy: 0.9564 - val_loss: 0.2375 - val_accuracy: 0.9247 - 695ms/epoch - 87ms/step
# Epoch 18/20
#
# Epoch 18: val_accuracy did not improve from 0.92471
# 8/8 - 1s - loss: 0.1001 - accuracy: 0.9588 - val_loss: 0.2321 - val_accuracy: 0.9247 - 675ms/epoch - 84ms/step
# Epoch 19/20
#
# Epoch 19: val_accuracy improved from 0.92471 to 0.94824, saving model to lstm_twitter_fix_model.h5
# 8/8 - 1s - loss: 0.0923 - accuracy: 0.9635 - val_loss: 0.2343 - val_accuracy: 0.9482 - 725ms/epoch - 91ms/step
# Epoch 20/20
#
# Epoch 20: val_accuracy did not improve from 0.94824
# 8/8 - 1s - loss: 0.0846 - accuracy: 0.9706 - val_loss: 0.2379 - val_accuracy: 0.9459 - 1s/epoch - 175ms/step
# Accuracy: 0.9458823800086975

# %%
# Define the plot_training_history function
def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Visualisasi Loss dan Akurasi
plot_training_history(history) # Call the function after it's defined

# %% [markdown]
# #**MODEL AWAL**

# %% [markdown]
# #**Jika Menghapus Duplikat**

# %%
# Menghapus duplikat
df.drop_duplicates(subset=['username'], keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948 entries, 0 to 2122
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_           948 non-null    int64
#  1   created_at    948 non-null    object
#  2   tweetID       948 non-null    object
#  3   tweet         948 non-null    object
#  4   username      948 non-null    object
#  5   Akun          948 non-null    object
#  6   id_str        948 non-null    int64
#  7   name          948 non-null    object
#  8   entity        948 non-null    object
#  9   commentcount  713 non-null    float64
#  10  likes         464 non-null    float64
#  11  retweets      464 non-null    float64
#  12  quotes        464 non-null    float64
#  13  replies       948 non-null    int64
#  14  sentiment     0 non-null      float64
#  15  bidang        0 non-null      float64
#  16  gender        0 non-null      float64
#  17  link          948 non-null    object
#  18  imageUrl      943 non-null    object
#  19  account_type  948 non-null    int64
# dtypes: float64(7), int64(4), object(9)
# memory usage: 155.5+ KB

# %%
print(df['Akun'].value_counts())
# Out:
# Akun
# AkunPribadi               521
# Unknown                   202
# AkunMediaMasa/Instansi    136
# AkunBisnis                 89
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    id_           created_at              tweetID  \
# 0    1  2023-01-01 13:50:44  1609547674893844481
# 1    2  2023-01-01 11:00:01  1609504712012795907
# 2    3   2023-01-02 9:41:59  1609847465347543042
# 3    4   2023-01-03 7:19:49  1610174074210160641
# 4    5   2023-01-03 2:29:01  1610100893583806465
#
#                                                tweet             username  \
# 0  Hallo, sobat Nedutase Lepas Sambut Kepala SMK ...             tan gsel
# 1  Shin Tae-yong selaku pelatih kepala Timnas Ind...                 pssi
# 2  SUZUKI XL 7 Jawabannya! Tampilan eksterior Suz...    gam pon gsuz uk i
# 3  Baru saja mengirim foto @ TOYOTA PERINTIS GATS...  toy ot am ed an _id
# 4  DIJUAL BMW E30 318i Mesin M10 Plat R Pajak On ...      hol den klas ik
#
#                      Akun               id_str                       name  \
# 0  AkunMediaMasa/Instansi  1414792059257380864               SMKN2Tangsel
# 1  AkunMediaMasa/Instansi           2363027508                       PSSI
# 2              AkunBisnis            971377286             Gampong Suzuki
# 3              AkunBisnis            732457105  Toyota Medan 082167506001
# 4              AkunBisnis           1391235014             Suka Mobil Tua
#
#        entity  commentcount      likes  retweets   quotes  replies  sentiment  \
# 0    Daihatsu           0.0        NaN       NaN      NaN        1        NaN
# 1  Mitsubishi          31.0  1837302.0     159.0  24686.0       31        NaN
# 2      Suzuki           0.0      140.0      72.0   1510.0        0        NaN
# 3      Toyota           0.0      642.0       1.0    757.0        0        NaN
# 4         BMW           1.0   154655.0     402.0  96590.0        1        NaN
#
#    bidang  gender                                               link  \
# 0     NaN     NaN                   https://twitter.com/TangselSmkn2
# 1     NaN     NaN  https://twitter.com/PSSI/status/16095047120127...
# 2     NaN     NaN  https://twitter.com/GampongSuzuki/status/16098...
# 3     NaN     NaN  https://twitter.com/toyotamedan_id/status/1610...
# 4     NaN     NaN  https://twitter.com/HoldenKlasik/status/161010...
#
#                                             imageUrl  account_type
# 0  https://pbs.twimg.com/profile_images/155974970...             3
# 1  https://pbs.twimg.com/media/FlYVvBCaUAA-LHy.jp...             3
# 2  https://pbs.twimg.com/media/FldTuxJakAQTrqR.jp...             3
# 3  https://pbs.twimg.com/profile_images/147098860...             0
# 4  https://pbs.twimg.com/media/Flg6NOsaUAAS5FA.jp...             3

# %% [markdown]
# #Epoch 10

# %% [markdown]
# MENGGUNAKAN DATA YANG SUDAH DIHAPUS DUPLIKATNYA
# *   Menghapus angka dan mengubah huruf menjadi lowercase.
# *   Menghapus simbol atau karakter spesial.
# *   Menghapus pengulangan kata.
# *   Memisahkan kata berdasarkan suku kata.

# %%
# 1. Menghapus angka dan mengubah huruf menjadi lowercase
df['username'] = df['username'].str.replace(r'\d+', '', regex=True).str.lower()

# 2. Menghapus simbol atau karakter spesial
df['username'] = df['username'].str.replace(r'[^\w\s]', '', regex=True)

# 3. Menghapus pengulangan kata
df['username'] = df['username'].apply(lambda x: ' '.join(sorted(set(x.split()), key=x.split().index)))

# 4. Memisahkan kata berdasarkan suku kata
# Misalnya, gunakan pendekatan sederhana memisahkan berdasarkan vokal
def split_syllables(word):
    syllables = re.findall(r'[^aiueo]*[aiueo]+(?:[^aiueo]|$)', word)
    return ' '.join(syllables)

df['username'] = df['username'].apply(lambda x: ' '.join([split_syllables(word) for word in x.split()]))

# Definisikan kriteria pengelompokan
personal_keywords = ["itsme", "mas", "pak", "bu", "bapak", "bunda", "bang", "bung", "muhammad", "muhamad", "zulkifli", "fuad", "faisal",
                     "aziz", "nur", "rifky", "tiwi", "kikim", "artha", "shandra", "sinatria", "zahra", "khairun", "budi", "eka", "ridwan"]

business_keywords = ["id", "honda", "yamaha", "daihatsu", "wuling", "toyota", "hyundai", "suzuki", "mobil", "jok", "bisnis",
                     "bmw", "klasik", "mobil", "indonesia"]

media_keywords = ["smk", "polri", "tv", "news", "online", "post", "kota", "harian", "fm", "radio", "tempo", "tribun", "kompas",
                  "detik", "berita", "tirtoid", "solopos", "antara", "media", "polda", "polsek", "dpc", "dpp", "liputan",
                  "times", "jpnn", "cnn", "coid", "harian", "dotco", "cnbc", "info", "detik", "tribun", "cnn"]

unknown_keywords = ["photo", "php", "reel", "speed", "gaya", "tetangga", "merapi", "geger", "cat", "random"]

def categorize_username(username):
    if any(keyword in username for keyword in personal_keywords):
        return 'AkunPribadi'
    elif any(keyword in username for keyword in business_keywords):
        return 'AkunBisnis'
    elif any(keyword in username for keyword in media_keywords):
        return 'AkunMediaMasa/Institusi'
    elif any(keyword in username for keyword in unknown_keywords):
        return 'Unknown'
    elif sum(c.isdigit() for c in username) > sum(c.isalpha() for c in username):
        return 'Unknown'
    else:
        return 'Unknown'

# Terapkan fungsi pengelompokan pada dataset
df['account_type'] = df['username'].apply(categorize_username)

# Encode label
label_encoder = LabelEncoder()
df['account_type'] = label_encoder.fit_transform(df['account_type'])

# Tokenize username
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['username'])
sequences = tokenizer.texts_to_sequences(df['username'])
X = pad_sequences(sequences, maxlen=15)  # 15 adalah panjang maksimal username yang akan dipertimbangkan
y = df['account_type']

# Pisahkan data menjadi training dan testing set (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1507)

# Bangun model LSTM
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50, input_length=15))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(4, activation='softmax'))  # 4 kelas output

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Menyimpan model terbaik berdasarkan akurasi validasi
checkpoint = ModelCheckpoint('lstm_twitter_coba_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Latih model
history = model.fit(X_train, y_train, epochs=10, batch_size=224, validation_data=(X_test, y_test), verbose=2, callbacks=[checkpoint])

# Evaluasi model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.88947, saving model to lstm_twitter_coba_model.h5
# 4/4 - 4s - loss: 1.3645 - accuracy: 0.5831 - val_loss: 1.2843 - val_accuracy: 0.8895 - 4s/epoch - 1s/step
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 1.2448 - accuracy: 0.8615 - val_loss: 1.1051 - val_accuracy: 0.8895 - 333ms/epoch - 83ms/step
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 1.0260 - accuracy: 0.8615 - val_loss: 0.7069 - val_accuracy: 0.8895 - 345ms/epoch - 86ms/step
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.6300 - accuracy: 0.8615 - val_loss: 0.5150 - val_accuracy: 0.8895 - 337ms/epoch - 84ms/step
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.6549 - accuracy: 0.8615 - val_loss: 0.4965 - val_accuracy: 0.8895 - 337ms/epoch - 84ms/step
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5509 - accuracy: 0.8615 - val_loss: 0.4493 - val_accuracy: 0.8895 - 337ms/epoch - 84ms/step
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5271 - accuracy: 0.8615 - val_loss: 0.5016 - val_accuracy: 0.8895 - 361ms/epoch - 90ms/step
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5451 - accuracy: 0.8615 - val_loss: 0.4653 - val_accuracy: 0.8895 - 380ms/epoch - 95ms/step
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5081 - accuracy: 0.8615 - val_loss: 0.4286 - val_accuracy: 0.8895 - 377ms/epoch - 94ms/step
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4963 - accuracy: 0.8615 - val_loss: 0.4268 - val_accuracy: 0.8895 - 337ms/epoch - 84ms/step
# Accuracy: 0.8894736766815186

# %%
# Define the plot_training_history function
def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Visualisasi Loss dan Akurasi
plot_training_history(history) # Call the function after it's defined

# %% [markdown]
# #Epoch 20

# %%
# 1. Menghapus angka dan mengubah huruf menjadi lowercase
df['username'] = df['username'].str.replace(r'\d+', '', regex=True).str.lower()

# 2. Menghapus simbol atau karakter spesial
df['username'] = df['username'].str.replace(r'[^\w\s]', '', regex=True)

# 3. Menghapus pengulangan kata
df['username'] = df['username'].apply(lambda x: ' '.join(sorted(set(x.split()), key=x.split().index)))

# 4. Memisahkan kata berdasarkan suku kata
# Misalnya, gunakan pendekatan sederhana memisahkan berdasarkan vokal
def split_syllables(word):
    syllables = re.findall(r'[^aiueo]*[aiueo]+(?:[^aiueo]|$)', word)
    return ' '.join(syllables)

df['username'] = df['username'].apply(lambda x: ' '.join([split_syllables(word) for word in x.split()]))

# Definisikan kriteria pengelompokan
personal_keywords = ["itsme", "mas", "pak", "bu", "bapak", "bunda", "bang", "bung", "muhammad", "muhamad", "zulkifli", "fuad", "faisal",
                     "aziz", "nur", "rifky", "tiwi", "kikim", "artha", "shandra", "sinatria", "zahra", "khairun", "budi", "eka", "ridwan"]

business_keywords = ["id", "honda", "yamaha", "daihatsu", "wuling", "toyota", "hyundai", "suzuki", "mobil", "jok", "bisnis",
                     "bmw", "klasik", "mobil", "indonesia"]

media_keywords = ["smk", "polri", "tv", "news", "online", "post", "kota", "harian", "fm", "radio", "tempo", "tribun", "kompas",
                  "detik", "berita", "tirtoid", "solopos", "antara", "media", "polda", "polsek", "dpc", "dpp", "liputan",
                  "times", "jpnn", "cnn", "coid", "harian", "dotco", "cnbc", "info", "detik", "tribun", "cnn"]

unknown_keywords = ["photo", "php", "reel", "speed", "gaya", "tetangga", "merapi", "geger", "cat", "random"]

def categorize_username(username):
    if any(keyword in username for keyword in personal_keywords):
        return 'AkunPribadi'
    elif any(keyword in username for keyword in business_keywords):
        return 'AkunBisnis'
    elif any(keyword in username for keyword in media_keywords):
        return 'AkunMediaMasa/Institusi'
    elif any(keyword in username for keyword in unknown_keywords):
        return 'Unknown'
    elif sum(c.isdigit() for c in username) > sum(c.isalpha() for c in username):
        return 'Unknown'
    else:
        return 'Unknown'

# Terapkan fungsi pengelompokan pada dataset
df['account_type'] = df['username'].apply(categorize_username)

# Encode label
label_encoder = LabelEncoder()
df['account_type'] = label_encoder.fit_transform(df['account_type'])

# Tokenize username
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['username'])
sequences = tokenizer.texts_to_sequences(df['username'])
X = pad_sequences(sequences, maxlen=15)  # 15 adalah panjang maksimal username yang akan dipertimbangkan
y = df['account_type']

# Pisahkan data menjadi training dan testing set (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1507)

# Bangun model LSTM
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50, input_length=15))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(4, activation='softmax'))  # 4 kelas output

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Menyimpan model terbaik berdasarkan akurasi validasi
checkpoint = ModelCheckpoint('lstm_twitter_coba2_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Latih model
history = model.fit(X_train, y_train, epochs=20, batch_size=224, validation_data=(X_test, y_test), verbose=2, callbacks=[checkpoint])

# Evaluasi model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/20
#
# Epoch 1: val_accuracy improved from -inf to 0.88947, saving model to lstm_twitter_coba2_model.h5
# 4/4 - 6s - loss: 1.3584 - accuracy: 0.6807 - val_loss: 1.2879 - val_accuracy: 0.8895 - 6s/epoch - 1s/step
# Epoch 2/20
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 1.2487 - accuracy: 0.8615 - val_loss: 1.1050 - val_accuracy: 0.8895 - 331ms/epoch - 83ms/step
# Epoch 3/20
#
# Epoch 3: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 1.0158 - accuracy: 0.8615 - val_loss: 0.6835 - val_accuracy: 0.8895 - 339ms/epoch - 85ms/step
# Epoch 4/20
#
# Epoch 4: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.6076 - accuracy: 0.8615 - val_loss: 0.5233 - val_accuracy: 0.8895 - 380ms/epoch - 95ms/step
# Epoch 5/20
#
# Epoch 5: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.6811 - accuracy: 0.8615 - val_loss: 0.5206 - val_accuracy: 0.8895 - 347ms/epoch - 87ms/step
# Epoch 6/20
#
# Epoch 6: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5859 - accuracy: 0.8615 - val_loss: 0.4334 - val_accuracy: 0.8895 - 342ms/epoch - 86ms/step
# Epoch 7/20
#
# Epoch 7: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5185 - accuracy: 0.8615 - val_loss: 0.4829 - val_accuracy: 0.8895 - 365ms/epoch - 91ms/step
# Epoch 8/20
#
# Epoch 8: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5426 - accuracy: 0.8615 - val_loss: 0.4822 - val_accuracy: 0.8895 - 359ms/epoch - 90ms/step
# Epoch 9/20
#
# Epoch 9: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5209 - accuracy: 0.8615 - val_loss: 0.4379 - val_accuracy: 0.8895 - 337ms/epoch - 84ms/step
# Epoch 10/20
#
# Epoch 10: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4982 - accuracy: 0.8615 - val_loss: 0.4260 - val_accuracy: 0.8895 - 410ms/epoch - 102ms/step
# Epoch 11/20
#
# Epoch 11: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.5013 - accuracy: 0.8615 - val_loss: 0.4254 - val_accuracy: 0.8895 - 342ms/epoch - 86ms/step
# Epoch 12/20
#
# Epoch 12: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4979 - accuracy: 0.8615 - val_loss: 0.4223 - val_accuracy: 0.8895 - 355ms/epoch - 89ms/step
# Epoch 13/20
#
# Epoch 13: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4868 - accuracy: 0.8615 - val_loss: 0.4243 - val_accuracy: 0.8895 - 373ms/epoch - 93ms/step
# Epoch 14/20
#
# Epoch 14: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4820 - accuracy: 0.8615 - val_loss: 0.4289 - val_accuracy: 0.8895 - 364ms/epoch - 91ms/step
# Epoch 15/20
#
# Epoch 15: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4790 - accuracy: 0.8615 - val_loss: 0.4229 - val_accuracy: 0.8895 - 344ms/epoch - 86ms/step
# Epoch 16/20
#
# Epoch 16: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4676 - accuracy: 0.8615 - val_loss: 0.4125 - val_accuracy: 0.8895 - 369ms/epoch - 92ms/step
# Epoch 17/20
#
# Epoch 17: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4638 - accuracy: 0.8615 - val_loss: 0.4052 - val_accuracy: 0.8895 - 334ms/epoch - 83ms/step
# Epoch 18/20
#
# Epoch 18: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4515 - accuracy: 0.8615 - val_loss: 0.4010 - val_accuracy: 0.8895 - 346ms/epoch - 87ms/step
# Epoch 19/20
#
# Epoch 19: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4368 - accuracy: 0.8615 - val_loss: 0.3984 - val_accuracy: 0.8895 - 372ms/epoch - 93ms/step
# Epoch 20/20
#
# Epoch 20: val_accuracy did not improve from 0.88947
# 4/4 - 0s - loss: 0.4258 - accuracy: 0.8615 - val_loss: 0.3940 - val_accuracy: 0.8895 - 350ms/epoch - 87ms/step
# Accuracy: 0.8894736766815186

# %%
# Define the plot_training_history function
def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Visualisasi Loss dan Akurasi
plot_training_history(history) # Call the function after it's defined
